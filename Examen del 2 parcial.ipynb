# %% [markdown]
# # Importamos las librerias que vamos a utilizar

# %%
#Panda es una libreria de python que nos permite hacer data frames
import pandas as pd

# %% [markdown]
# #Extraemos los datos que vamos a utilizar

# %%
#Panda es una libreria de python que nos permite hacer data frames
import pandas as pd
#Numpy es para operaciones de matrices
import numpy as np
#Seaborn es para graficar y hacer comparativos
import seaborn as sns

#Graficas de forma general
#import matplotlib as plt
from matplotlib import pyplot as plt
# %matplotlib inline 

#Importar una libreria  faltante

# %%
# !unzip spotify_dataset.zip
# Out:
# Archive:  spotify_dataset.zip
#   inflating: data.csv
#   inflating: data_by_artist.csv
#   inflating: data_by_genres.csv
#   inflating: data_by_year.csv
#   inflating: data_w_genres.csv

# %%
#Creamos las variables para poder hacer dataframes con lo extraido anteriormente
df = pd.read_csv("data.csv", encoding='latin')

# %%
df
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %% [markdown]
# # Se ordenan 10 datos alfabéticamente

# %%
sp = df.head(10).sort_values(by='artists', ascending=True)

# %%
sp
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %% [markdown]
# # Se correlacionan los datos

# %%
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.263217    -0.089169 -0.750852 -0.208176
# danceability         -0.263217      1.000000    -0.100757  0.204838  0.200842
# duration_ms          -0.089169     -0.100757     1.000000  0.060516 -0.033808
# energy               -0.750852      0.204838     0.060516  1.000000  0.102561
# explicit             -0.208176      0.200842    -0.033808  0.102561  1.000000
# instrumentalness      0.221956     -0.215589     0.103621 -0.177750 -0.130609
# key                  -0.028028      0.026266     0.002020  0.035780  0.005282
# liveness             -0.029654     -0.110033     0.028942  0.134815  0.037288
# loudness             -0.546639      0.249541     0.019791  0.779267  0.106249
# mode                  0.064633     -0.048358    -0.046849 -0.056160 -0.062503
# popularity           -0.396744      0.123746     0.024717  0.328939  0.152545
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %% [markdown]
# # En está seccion se puede observar los datos entre la popularidad  y el año para poder analizar que estaba de moda en ese tiempo

# %%
relation = df[['popularity','name','year']]

# %%
relation
# Out:
#         duration_ms    tempo
# 0            168333  149.976
# 1            150200   86.889
# 2            163827   97.600
# 3            422087  127.997
# 4            165224  122.076
# ...             ...      ...
# 174384       147615  125.972
# 174385       144720   94.710
# 174386       218147  108.058
# 174387       244000  171.319
# 174388       197710  112.208
#
# [174389 rows x 2 columns]

# %% [markdown]
# #En está se puede ver como el tiempo y la duracion tienen una relacion

# %%
relation1 = df[['duration_ms','tempo']]

# %%
relation1
# Out:
#         duration_ms    tempo
# 0            168333  149.976
# 1            150200   86.889
# 2            163827   97.600
# 3            422087  127.997
# 4            165224  122.076
# ...             ...      ...
# 174384       147615  125.972
# 174385       144720   94.710
# 174386       218147  108.058
# 174387       244000  171.319
# 174388       197710  112.208
#
# [174389 rows x 2 columns]

# %% [markdown]
# # Aquí sacamos la moda, promedio, varianza valores maximos y minimos

# %%
df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Por ultimo sacamos las relaciones lineales

# %%
#Numpy es para operaciones de matrices
import numpy as np
#Seaborn es para graficar y hacer comparativos
import seaborn as sns

#Graficas de forma general
#import matplotlib as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(relation, kind='reg')
plt.show()

# %%
sns.pairplot(relation1, kind='reg')
plt.show()

# %%
sns.lmplot(x='mode', y='year', data=df)

# %% [markdown]
# En esté caso la que puede tener relación lineal positiva es entre el año y la moda lo considero así porque cada año va cambiando la moda de un artista y el genero asi que cada año va subiendo este dato
